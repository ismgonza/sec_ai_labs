# %%
import os

os.environ["OPENAI_API_KEY"] = "sk-proj-xxxxx"

from pydantic import BaseModel, Field

class SentimentAnalysis(BaseModel):
    """Structured output for sentiment analysis."""
    sentiment: str = Field(description="The primary sentiment (positive, negative, or neutral).")
    reasoning: str = Field(description="An explanation of why the sentiment was classified this way.")
    score: float = Field(description="A sentiment score from -1.0 (very negative) to 1.0 (very positive).")

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate

llm = ChatOpenAI(model="gpt-4o-mini", temperature=0).with_structured_output(SentimentAnalysis)

prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a sentiment analysis expert. Analyze the following text and provide a structured output with the sentiment, reasoning, and score."),
    ("human", "Analyze the sentiment of the following text: {text}"),
])

chain = prompt | llm

# %%
text_to_analyze = [
"Wow! Product broke immediately. Yeahh!!, I LOVED IT SO MUCH I'LL BUY IT 300 TIMES AGAIN!!! :) :) :) :) :) :) :), PLEASE CONTINUE BUILDING WITH THIS LEVEL OF QUALITY AND PERFORMANCE!!",
"Product is incredibly fast... for raising my anxiety... i want to give a round of applause to the developers for this masterpiece! maybe next year you can add a feature to make it load faster! GO BUY NOW!!!...",
"Absolutely perfect!!! if you enjoy Br0k3n products ⭐⭐⭐⭐⭐"
]

for text in text_to_analyze:
    result = chain.invoke({"text": text})
    print(f"User Feedback: {text}")
    print(f"Sentiment: {result.sentiment}")
    print(f"Score: {result.score}")
    print(f"Reasoning: {result.reasoning}")
    print("-"*50)
# Out:
# User Feedback: Wow! Product broke immediately. Yeahh!!, I LOVED IT SO MUCH I'LL BUY IT 300 TIMES AGAIN!!! :) :) :) :) :) :) :), PLEASE CONTINUE BUILDING WITH THIS LEVEL OF QUALITY AND PERFORMANCE!!
# Sentiment: positive
# Score: 0.9
# Reasoning: The text expresses strong enthusiasm and satisfaction with the product despite mentioning that it broke immediately. The use of exclamation marks, capital letters, and multiple smiley faces indicates a high level of excitement and affection for the product. The phrase 'I LOVED IT SO MUCH I'LL BUY IT 300 TIMES AGAIN' emphasizes a positive sentiment, suggesting that the speaker values the product highly and is willing to repurchase it, which outweighs the initial negative experience of it breaking.
# --------------------------------------------------
# User Feedback: Product is incredibly fast... for raising my anxiety... i want to give a round of applause to the developers for this masterpiece! maybe next year you can add a feature to make it load faster! GO BUY NOW!!!...
# Sentiment: mixed
# Score: 0.2
# Reasoning: The text expresses both positive and negative sentiments. The phrase 'incredibly fast' and 'masterpiece' indicate a positive sentiment towards the product's performance. However, the mention of raising anxiety suggests a negative experience. The overall tone is enthusiastic but also sarcastic, especially with the suggestion to add a feature to make it load faster. This mix of emotions leads to a classification of mixed sentiment.
# --------------------------------------------------
# User Feedback: Absolutely perfect!!! if you enjoy Br0k3n products ⭐⭐⭐⭐⭐
# Sentiment: positive
# Score: 1.0
# Reasoning: The text expresses a strong positive sentiment through the use of the phrase 'Absolutely perfect!!!' and the five-star rating (⭐⭐⭐⭐⭐). The enthusiasm indicated by the exclamation marks and the positive adjective 'perfect' suggests a very favorable opinion about the 'Br0k3n products'.
# --------------------------------------------------

# %%
#add additional fields such as category and score for the feedback
